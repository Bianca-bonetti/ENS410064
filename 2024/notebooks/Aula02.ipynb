# %% [markdown]
# # Aula 02
# Nesta aula veremos:
#
# - (continuação dos tipos de variáveis)
# - pacote numpy
# - pacote pandas
# - matplotlib - plotagem de figuras

# %% [markdown]
# ## Continuação dos tipos de variáveis

# %%
# Exemplo lista

a = [1,2,3,10,20,30]

# Indexação da lista = a[0] = 1
print(a[0])

# Acessando o último valor da lista
print(a[-1])
# Out:
# 1
# 30

# %%
# Determinando o comprimento da lista

b = len(a)
print('O comprimento da lista a é: ' + str(b))

# acessando o último valor da lista
print('O último valor da lista é: ' + str(a[b-1]))
# Out:
# O comprimento da lista a é: 6
# O último valor da lista é: 30

# %% [markdown]
# ## O pacote numpy
#
# https://numpy.org/
#
# Este pacote serve para operações matriciais e estatísticas básicas.

# %%
# Importando o numpy
import numpy as np

# %%
# Criando um vetor número aleatório com numpy
c = np.random.rand(100)
#print(c)
print(type(c))

# acessando o último valor do array numpy
print('O último valor de c é:' + str(c[-1]))
print("")

# acessando os 10 primeiros valores
print('Os 10 primeiros valores da lista são:'+str(c[0:10]))

# Loop com um numpy array
for ii in range(0,10):
    print(str(ii) +' '+ str(c[ii]))

print("")

# O comprimento do numpy array - shape da matriz
print('O shape da matriz c é:')
print(np.shape(c))
# Out:
# <class 'numpy.ndarray'>
# O último valor de c é:0.6333124645383956
#
# Os 10 primeiros valores da lista são:[0.20072825 0.6400396  0.88338564 0.92166881 0.46177416 0.2824795
#  0.13608367 0.81592621 0.14216371 0.23259941]
# 0 0.20072825465978184
# 1 0.640039600692461
# 2 0.8833856449580674
# 3 0.9216688131811331
# 4 0.46177415774640695
# 5 0.28247949692498575
# 6 0.13608367157747803
# 7 0.8159262136972847
# 8 0.14216370767540865
# 9 0.23259941396975958
#
# O shape da matriz c é:
# (100,)

# %%
# Criando uma matriz numpy
d = np.random.rand(100,100)
print(d)

print('Qual é o shape/dimensão da matriz?')
print(np.shape(d))

# Acessando a matriz numpy
# linha 11 e coluna 11
print('Indexação numpy - matriz 2D')
print(d[10,10])
# Out:
# [[0.05065635 0.85177038 0.85832105 ... 0.63543306 0.54504155 0.01100519]
#  [0.79086939 0.05368137 0.07440882 ... 0.21122423 0.95133192 0.41337113]
#  [0.21661511 0.8813951  0.3107331  ... 0.9172706  0.92894768 0.44620572]
#  ...
#  [0.33407856 0.18565277 0.8666687  ... 0.1798334  0.73564104 0.91445903]
#  [0.43277437 0.6599706  0.6175615  ... 0.80188107 0.72955497 0.07378136]
#  [0.95503851 0.71027136 0.0983011  ... 0.91925021 0.29955019 0.40617123]]
# Qual é o shape/dimensão da matriz?
# (100, 100)
# Indexação numpy - matriz 2D
# 0.6015952930067974

# %%
# Gerando uma matriz 3D

mat3D = np.random.rand(365,100,100)
print(np.shape(mat3D))
# Out:
# (365, 100, 100)

# %%
# Acessando todos os valores da primeira dimensão na célula 49,49

# Todos os valores da série
timeSeries = mat3D[:,49,49]
print(timeSeries)

# 10 primeiros valores da série
timeSeries = mat3D[:10,49,49]
print(timeSeries)

# 10 últimos valores da série
timeSeries = mat3D[-10:,49,49]
print(timeSeries)
# Out:
# [0.48090718 0.5598361  0.24708906 0.36745939 0.57733008 0.11036603
#  0.59298079 0.48574883 0.73381025 0.32084044 0.11966697 0.34391982
#  0.44670325 0.33753544 0.09260035 0.60502137 0.63613039 0.44180685
#  0.09762021 0.39512172 0.52934133 0.80784739 0.9033053  0.76242032
#  0.57379948 0.57208216 0.57714333 0.72521656 0.00882497 0.15779141
#  0.2439313  0.58752727 0.93217383 0.30225308 0.02395341 0.38080656
#  0.70458004 0.7628885  0.35001991 0.85434438 0.31450788 0.92268009
#  0.64647959 0.02447539 0.6243594  0.70965007 0.36066245 0.05161447
#  0.01368157 0.32263534 0.58603943 0.57503726 0.25450832 0.25928636
#  0.42627778 0.77682183 0.52442983 0.66185961 0.45213279 0.56559207
#  0.8634483  0.29059674 0.96145508 0.53138681 0.79485954 0.27167996
#  0.51429606 0.9685251  0.96104443 0.9208104  0.02576148 0.56236318
#  0.62247916 0.2598461  0.5222559  0.24021496 0.76781061 0.1848025
#  0.08829699 0.61106588 0.26709501 0.65920886 0.33477039 0.61741845
#  0.57541851 0.44911113 0.02667982 0.52413436 0.65197    0.45664446
#  0.29866263 0.93570549 0.99707486 0.57749322 0.24267987 0.58576811
#  0.57637611 0.13216618 0.55732839 0.97349351 0.02922697]
# [0.48090718 0.5598361  0.24708906 0.36745939 0.57733008 0.11036603
#  0.59298079 0.48574883 0.73381025 0.32084044]
# [0.93570549 0.99707486 0.57749322 0.24267987 0.58576811 0.57637611
#  0.13216618 0.55732839 0.97349351 0.02922697]

# %%
# Operações matriciais com numpy

timeSeries2 = mat3D[:,50:52,50]
print(np.shape(timeSeries2))
print(timeSeries2.shape)

# Matriz transposta
timeSeriesTransposta = timeSeries2.transpose()
print(timeSeriesTransposta.shape)

timeSeriesTransposta = np.transpose(timeSeries2)
print(timeSeriesTransposta.shape)
# Out:
# (365, 2)
# (365, 2)
# (2, 365)
# (2, 365)

# %%
# Estatísticas com numpy

# Média de todos os valores
print('Essa é a média de todos os valores')
mediaTS = np.mean(timeSeries2)
print(mediaTS)

# Média nas colunas
print('Essa é a média de cada coluna')
mediaTScolumns = np.mean(timeSeries2,axis=0)
print(mediaTScolumns)
#print(timeSeries2)

# Média nas linhas 
print('Essa é a média de cada linha')
mediaTSrows = np.mean(timeSeries2,axis=1)
print(mediaTSrows.shape)
#print(timeSeries2)

# Média na terceira dimensão
media3D = np.mean(mat3D,axis=0)
print(media3D)
print(media3D.shape)
# Out:
# Essa é a média de todos os valores
# 0.5210231044828268
# Essa é a média de cada coluna
# [0.51924949 0.52279672]
# Essa é a média de cada linha
# (365,)
# [[0.50477913 0.51909402 0.49806142 ... 0.48171596 0.48855221 0.49539186]
#  [0.52444464 0.49180278 0.51326545 ... 0.51138802 0.52395061 0.5057238 ]
#  [0.51845682 0.48789875 0.50104191 ... 0.4975992  0.50055621 0.50379646]
#  ...
#  [0.51331126 0.48308374 0.52868834 ... 0.51316268 0.51492449 0.50335076]
#  [0.53259968 0.48725209 0.5056255  ... 0.47906044 0.50496718 0.48722412]
#  [0.49405104 0.50522832 0.48885469 ... 0.48021577 0.50159647 0.51443798]]
# (100, 100)

# %%
# Média, mínimo, máximo, desvio, percentil, mediana, variancia

# Média
media3D = np.mean(mat3D)
print(media3D)

# Mínimo
min3D = np.min(mat3D)
print(min3D)

# Máximo
media3D = np.max(mat3D)
print(media3D)

# Média
max3D = np.mean(mat3D)
print(max3D)

# Desvio
std3D = np.std(mat3D)
print(std3D)

# percentil
pct3D = np.percentile(mat3D,90)
print(pct3D)

# mediana
median3D = np.median(mat3D)
print(median3D)

# variância
var3D = std3D**2
print(var3D)
var3D = np.var(mat3D)
print(var3D)
# Out:
# 0.49987286548766235
# 4.7418371007523774e-08
# 0.9999998908085515
# 0.49987286548766235
# 0.28859273935862695
# 0.8997563630631554
# 0.49991820719521113
# 0.08328576921051639
# 0.08328576921051638

# %%
# Concatenação
mat3D2 = mat3D.copy()

matConcat = np.concatenate([mat3D,mat3D2])
print(matConcat.shape)
# Out:
# (730, 100, 100)

# %% [markdown]
# ## Plotando com matplotlib
#
# https://matplotlib.org/
#
# - plot
# - histogram
# - bar
# - boxplot
# - pcolor
# - scatter

# %%
# importando o pactote matplotlib
import matplotlib.pyplot as plt

# Criando um objeto matplotlib para plotar as figuras
fig,ax = plt.subplots(3)

# lineplot
ax[0].plot(mat3D[:,10,10])
ax[1].plot(mat3D[:,10:12,10])

# bar
ax[2].bar(np.array(range(0,mat3D.shape[0])),mat3D[:,10,10])
print(type(range(0,mat3D.shape[0])))
# Out:
# <class 'range'>

# %%
# BOXPLOT

fig, ax = plt.subplots(2)
ax[0].boxplot(mat3D[:,10:20,0].flatten())
ax[1].boxplot(mat3D[:,10:20,0])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b667d77160>,
#   <matplotlib.lines.Line2D at 0x1b667d77400>,
#   <matplotlib.lines.Line2D at 0x1b667d84400>,
#   <matplotlib.lines.Line2D at 0x1b667d846a0>,
#   <matplotlib.lines.Line2D at 0x1b667d926a0>,
#   <matplotlib.lines.Line2D at 0x1b667d92940>,
#   <matplotlib.lines.Line2D at 0x1b667d9e940>,
#   <matplotlib.lines.Line2D at 0x1b667d9ebe0>,
#   <matplotlib.lines.Line2D at 0x1b667dacbe0>,
#   <matplotlib.lines.Line2D at 0x1b667dace80>,
#   <matplotlib.lines.Line2D at 0x1b667db9e80>,
#   <matplotlib.lines.Line2D at 0x1b667dc5160>,
#   <matplotlib.lines.Line2D at 0x1b667dd3160>,
#   <matplotlib.lines.Line2D at 0x1b667dd3400>,
#   <matplotlib.lines.Line2D at 0x1b667de0400>,
#   <matplotlib.lines.Line2D at 0x1b667de06a0>,
#   <matplotlib.lines.Line2D at 0x1b667ded6a0>,
#   <matplotlib.lines.Line2D at 0x1b667ded940>,
#   <matplotlib.lines.Line2D at 0x1b667a74220>,
#   <matplotlib.lines.Line2D at 0x1b667a74460>],
#  'caps': [<matplotlib.lines.Line2D at 0x1b667d776a0>,
#   <matplotlib.lines.Line2D at 0x1b667d77940>,
#   <matplotlib.lines.Line2D at 0x1b667d84940>,
#   <matplotlib.lines.Line2D at 0x1b667d84be0>,
#   <matplotlib.lines.Line2D at 0x1b667d92be0>,
#   <matplotlib.lines.Line2D at 0x1b667d92e80>,
#   <matplotlib.lines.Line2D at 0x1b667d9ee80>,
#   <matplotlib.lines.Line2D at 0x1b667dac160>,
#   <matplotlib.lines.Line2D at 0x1b667db9160>,
#   <matplotlib.lines.Line2D at 0x1b667db9400>,
#   <matplotlib.lines.Line2D at 0x1b667dc5400>,
#   <matplotlib.lines.Line2D at 0x1b667dc56a0>,
#   <matplotlib.lines.Line2D at 0x1b667dd36a0>,
#   <matplotlib.lines.Line2D at 0x1b667dd3940>,
#   <matplotlib.lines.Line2D at 0x1b667de0940>,
#   <matplotlib.lines.Line2D at 0x1b667de0be0>,
#   <matplotlib.lines.Line2D at 0x1b667dedbe0>,
#   <matplotlib.lines.Line2D at 0x1b667dede80>,
#   <matplotlib.lines.Line2D at 0x1b667a744f0>,
#   <matplotlib.lines.Line2D at 0x1b667a74b20>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1b667d68e80>,
#   <matplotlib.lines.Line2D at 0x1b667d84160>,
#   <matplotlib.lines.Line2D at 0x1b667d92400>,
#   <matplotlib.lines.Line2D at 0x1b667d9e6a0>,
#   <matplotlib.lines.Line2D at 0x1b667dac940>,
#   <matplotlib.lines.Line2D at 0x1b667db9be0>,
#   <matplotlib.lines.Line2D at 0x1b667dc5e80>,
#   <matplotlib.lines.Line2D at 0x1b667de0160>,
#   <matplotlib.lines.Line2D at 0x1b667ded400>,
#   <matplotlib.lines.Line2D at 0x1b6650bba00>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b667d77be0>,
#   <matplotlib.lines.Line2D at 0x1b667d84e80>,
#   <matplotlib.lines.Line2D at 0x1b667d9e160>,
#   <matplotlib.lines.Line2D at 0x1b667dac400>,
#   <matplotlib.lines.Line2D at 0x1b667db96a0>,
#   <matplotlib.lines.Line2D at 0x1b667dc5940>,
#   <matplotlib.lines.Line2D at 0x1b667dd3be0>,
#   <matplotlib.lines.Line2D at 0x1b667de0e80>,
#   <matplotlib.lines.Line2D at 0x1b667df8160>,
#   <matplotlib.lines.Line2D at 0x1b667a74a60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b667d77e80>,
#   <matplotlib.lines.Line2D at 0x1b667d92160>,
#   <matplotlib.lines.Line2D at 0x1b667d9e400>,
#   <matplotlib.lines.Line2D at 0x1b667dac6a0>,
#   <matplotlib.lines.Line2D at 0x1b667db9940>,
#   <matplotlib.lines.Line2D at 0x1b667dc5be0>,
#   <matplotlib.lines.Line2D at 0x1b667dd3e80>,
#   <matplotlib.lines.Line2D at 0x1b667ded160>,
#   <matplotlib.lines.Line2D at 0x1b667df8400>,
#   <matplotlib.lines.Line2D at 0x1b667a74f70>],
#  'means': []}

# %%
# pcolor - gráfico de superfície

fig, ax = plt.subplots(2,2)

ax[0,0].pcolor(mat3D[0,:,:],cmap='gray')
ax[0,1].contour(np.sin(mat3D[0,:,:]))
ax[1,1].scatter(np.sin(mat3D[0,:,:]).flatten(),mat3D[0,:,:].flatten())
ax[1,0].hist(np.sin(mat3D[0,:,:]).flatten())
# Out:
# (array([ 874.,  825.,  860.,  907.,  919.,  939.,  990., 1093., 1201.,
#         1392.]),
#  array([3.41891802e-04, 8.44455433e-02, 1.68549195e-01, 2.52652846e-01,
#         3.36756498e-01, 4.20860149e-01, 5.04963801e-01, 5.89067452e-01,
#         6.73171103e-01, 7.57274755e-01, 8.41378406e-01]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Utilizando o pandas
#
# https://pandas.pydata.org/
#
# Esta biblioteca é sensacional!

# %%
import pandas as pd

# %% [raw]
# path = r'C:\Users\Leonardo.Hoinaski\Documents\ENS410064\2024\dados\metar.csv'
# df = pd.read_csv(path)
# df.head()

# %% [raw]
# df.mean()

# %% [raw]
# df.describe()

# %% [raw]
# # plotando com dataframe
# fig, ax = plt.subplots(4)
#
# df['temp'].plot(ax=ax[0])
# df['cco'][df.year==2022].plot(ax=ax[1],color='red')
# df.boxplot(column=['ws'], by='month', ax=ax[2])
# # Remove background grid lines
# ax[2].grid(False)

# %% [raw]
# from windrose import WindroseAxes
#
# ax = WindroseAxes.from_ax()
# ax.bar(df['wd'], df['ws'], normed=True, opening=0.8, edgecolor="white")
# ax.set_legend()
